# %%
a, b = map(int, input().split())
s = str(a) + str(b)
num = int(s)
flag = False
for i in range(1, 318):
    if i **2 == num:
        flag = True
if flag:
    print("Yes")
else:
    print("No")
# Out:
# No

# %%
350**2
# Out:
# 122500

# %%
import math

# %%
math.sqrt(100100)
# Out:
# 316.3858403911275

# %%
317**2
# Out:
# 100489
