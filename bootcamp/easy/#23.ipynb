# %%
#切り上げを用いることでもi人目が食べたチョコレートの合計を求めることができる
n = int(input())
d, x = map(int, input().split())
csum = 0
for i in range(n):
    a = int(input())
    now = 1
    csum += 1
    while True:
        now += a
        if now > d:
            break
        csum += 1
print(csum + x)
# Out:
# 1
# 3
# 5
# 7
# 1
# 6
# 11
# 1
# 6
# 11
# 11
