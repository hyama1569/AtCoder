# %%
n = int(input())
a = list(map(int, input().split()))
idx = [i for i in range(1, n+1)]
ls = []
for i, j in zip(idx, a):
    ls.append((i, j))
ls = sorted(ls, key=lambda x:x[1], reverse=False)
ans = [i[0] for i in ls]
print(*ans)
# Out:
# 1 2 3

# %%
ls
# Out:
# [(3, 1), (1, 2), (2, 3)]
