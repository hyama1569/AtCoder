# %%
n = int(input())

l0 = 2
l1 = 1
ls = [l0, l1]

if n == 1:
    print(l1)
else:
    for i in range(2, n+1):
        l2 = ls[i-2] + ls[i-1]
        ls.append(l2)
    print(ls[-1])
# Out:
# 11

# %%
list(range(2, 5))
# Out:
# [2, 3, 4]
