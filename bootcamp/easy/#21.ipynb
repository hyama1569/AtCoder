# %%
x = int(input())

def is_prime(n):
    if n <= 1:
        return False
    for j in range(2, int(n**0.5) + 1):
        if n%j == 0:
            return False
    return True

while True:
    if is_prime(x):
        print(x)
        break
    x += 1
# Out:
# 100003
