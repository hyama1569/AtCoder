# %%
n = int(input())
ls = []
for i in range(n):
    ls.append(int(input()))

ls2 = sorted(ls, reverse=True)
big1 = ls2[0]
big2 = ls2[1]

for i in range(len(ls)):
    if ls[i] == big1:
        print(big2)
    else:
        print(big1)
