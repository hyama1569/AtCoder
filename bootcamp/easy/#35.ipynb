# %%
s = input()
all = "abcdefghijklmnopqrstuvwxyz"
d = {}
for c in all:
    d[c] = 0
for c in s:
    d[c] += 1

flag = False
for k, v in d.items():
    if v == 0:
        print(k)
        flag = True
        break
if flag == False:
    print("None")
# Out:
# b

# %%
d
# Out:
# {'a': 0,
#  'b': 0,
#  'c': 0,
#  'd': 0,
#  'e': 0,
#  'f': 0,
#  'g': 0,
#  'h': 0,
#  'i': 0,
#  'j': 0,
#  'k': 0,
#  'l': 0,
#  'm': 0,
#  'n': 0,
#  'o': 0,
#  'p': 0,
#  'q': 0,
#  'r': 0,
#  's': 0,
#  't': 0,
#  'u': 0,
#  'v': 0,
#  'w': 0,
#  'x': 0,
#  'y': 0,
#  'z': 0}
