# %%
k, n = map(int, input().split())
a = list(map(int, input().split()))
between = []
between.append(a[0] + k - a[-1])
for i in range(len(a)-1):
    between.append(a[i+1] - a[i])
print(k - max(between))
